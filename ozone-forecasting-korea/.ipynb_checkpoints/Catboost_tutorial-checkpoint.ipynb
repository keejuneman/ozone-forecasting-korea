# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from catboost import CatBoostRegressor
import optuna
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv('test-data/2022_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4baebe95e7f0> in <module>
# ----> 1 data = pd.read_csv('/kaggle/input/test-data/2022_dataset.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Check NaN
#
# - PRE : 강수량 NaN 값 0으로 처리
# - RH : 상대습도
# - DT : 일조시간

# %%
data.isnull().sum()
# Out:
# Date        0
# AT          0
# MinT        0
# MaxT        0
# PRE       261
# AWS         0
# MaxWD       0
# MaxIWD      0
# MaxWS       0
# MaxIWS      0
# RH          1
# DT         39
# CA          0
# Result      0
# dtype: int64

# %%
data[data['PRE'].isnull()]
# Out:
#            Date   AT  MinT  MaxT  PRE  AWS  MaxWD  MaxIWD  MaxWS  MaxIWS  \
# 0    2022-01-01 -4.3 -10.2   2.3  NaN  1.5      2       4    2.8     4.5
# 2    2022-01-03 -1.9  -8.0   2.5  NaN  1.8     12      13    4.1     6.9
# 3    2022-01-04 -2.5  -5.6   1.0  NaN  2.4     12      13    4.2     6.8
# 4    2022-01-05 -2.8  -7.8   1.9  NaN  1.7      3       3    2.9     4.2
# 5    2022-01-06 -2.2  -5.9   3.3  NaN  2.3     14      14    4.6     7.8
# ..          ...  ...   ...   ...  ...  ...    ...     ...    ...     ...
# 359  2022-12-26 -3.9  -7.9   1.7  NaN  1.4      3      16    2.8     3.7
# 360  2022-12-27 -2.6  -7.3   3.3  NaN  1.8     14      14    3.2     5.4
# 362  2022-12-29 -2.9  -7.8   2.1  NaN  1.7     14      15    3.4     5.1
# 363  2022-12-30 -1.8  -4.4   2.3  NaN  1.9     13      13    4.6     7.5
# 364  2022-12-31 -1.2  -5.1   2.1  NaN  1.4     16       1    2.6     4.1
#
#        RH   DT   CA  Result
# 0    46.3  9.0  1.4  0.0125
# 2    58.3  7.8  4.9  0.0086
# 3    51.8  9.0  0.0  0.0170
# 4    47.6  1.9  7.3  0.0062
# 5    47.1  9.1  0.0  0.0130
# ..    ...  ...  ...     ...
# 359  68.4  7.6  1.4  0.0061
# 360  69.8  8.8  0.1  0.0066
# 362  56.3  9.0  3.3  0.0127
# 363  65.6  7.9  1.4  0.0150
# 364  65.5  1.1  7.4  0.0074
#
# [261 rows x 14 columns]

# %%
data[data['DT'].isnull()]
# Out:
#        Date    AT  MinT  MaxT    PRE  AWS  MaxWD  MaxIWD  MaxWS  MaxIWS    RH  \
# 18   220119  -5.3  -7.7  -2.7    1.7  2.1     15      15    4.7     8.3  72.3
# 24   220125   2.8   1.9   4.5    0.7  2.3     13      12    4.9     7.7  80.0
# 71   220313  11.7  10.7  12.6   42.1  1.9     15      10    4.8     9.5  95.5
# 72   220314   8.2   4.9  13.2    8.7  3.2     12      12    6.2    12.0  90.3
# 76   220318   7.5   5.5   9.6    NaN  4.4      3       4    7.1    12.3  60.8
# 77   220319   3.4   0.9   6.1   14.6  3.0      3       4    4.9     8.7  84.6
# 81   220323   6.2   4.9   8.2    NaN  2.3     12      13    4.0     7.8  56.8
# 102  220413  13.1  12.0  15.9    1.3  4.4      3       3    8.4    14.5  69.3
# 103  220414  13.2  11.4  15.3    NaN  4.0      3       3    6.6    11.1  53.4
# 111  220422  15.0  13.2  16.8    NaN  3.5     11      10    6.6    11.7  76.8
# 127  220508  15.3  11.7  18.2    2.0  2.8      3       3    5.2    10.6  51.8
# 165  220615  17.5  14.9  20.1   18.5  2.3      4       3    3.7     7.4  92.4
# 179 NaN  10.0  0.0146
# 180 NaN  10.0  0.0319
# 188 NaN   9.5  0.0427
# 193 NaN  10.0  0.0190
# 205 NaN   3.8  0.0258
# 211 NaN   9.8  0.0120
# 213 NaN   9.9  0.0157
# 219 NaN  10.0  0.0324
# 220 NaN  10.0  0.0306
# 226 NaN   9.5  0.0268
# 230 NaN   9.3  0.0265
# 236 NaN   8.3  0.0175
# 240 NaN   9.9  0.0182
# 241 NaN  10.0  0.0163
# 243 NaN   1.0  0.0225
# 247 NaN  10.0  0.0401
# 248 NaN   3.9  0.0504
# 275 NaN  10.0  0.0211
# 316 NaN   8.8  0.0163
# 348 NaN   7.3  0.0070
# 354 NaN   8.5  0.0116

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## To datetime

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ### 1. YYMMDD

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.strftime('%y%m%d')
df['Date'] = df['Date'].astype(int)

# %%
df
# Out:
#        Date   AT  MinT  MaxT  PRE  AWS  MaxWD  MaxIWD  MaxWS  MaxIWS    RH  \
# 0    700101 -4.3 -10.2   2.3  NaN  1.5      2       4    2.8     4.5  46.3
# 1    700101 -1.3  -5.2   3.0  0.3  2.3     14      14    4.6     8.1  57.9
# 2    700101 -1.9  -8.0   2.5  NaN  1.8     12      13    4.1     6.9  58.3
# 3    700101 -2.5  -5.6   1.0  NaN  2.4     12      13    4.2     6.8  51.8
# 4    700101 -2.8  -7.8   1.9  NaN  1.7      3       3    2.9     4.2  47.6
# ..      ...  ...   ...   ...  ...  ...    ...     ...    ...     ...   ...
# 360  700101 -2.6  -7.3   3.3  NaN  1.8     14      14    3.2     5.4  69.8
# 361  700101 -3.3  -6.0   0.1  0.1  2.5     14      13    4.9     8.7  58.1
# 362  700101 -2.9  -7.8   2.1  NaN  1.7     14      15    3.4     5.1  56.3
# 363  700101 -1.8  -4.4   2.3  NaN  1.9     13      13    4.6     7.5  65.6
# 364  700101 -1.2  -5.1   2.1  NaN  1.4     16       1    2.6     4.1  65.5
#
#       DT   CA  Result  Year  Month  Day
# 0    9.0  1.4  0.0125  1970      1    1
# 1    5.4  4.1  0.0164  1970      1    1
# 2    7.8  4.9  0.0086  1970      1    1
# 3    9.0  0.0  0.0170  1970      1    1
# 4    1.9  7.3  0.0062  1970      1    1
# ..   ...  ...     ...   ...    ...  ...
# 360  8.8  0.1  0.0066  1970      1    1
# 361  8.7  3.3  0.0180  1970      1    1
# 362  9.0  3.3  0.0127  1970      1    1
# 363  7.9  1.4  0.0150  1970      1    1
# 364  1.1  7.4  0.0074  1970      1    1
#
# [365 rows x 17 columns]

# %%
# YYMMDD
features = [
            'Date', 
            'AT', 
            'MinT', 
            'MaxT', 
            'PRE', 
            'AWS', 
            'MaxWD', 
            'MaxIWD', 
            'MaxWS',
            'MaxIWS', 
            'RH', 
            'DT', 
            'CA', 
           ]

# %% [markdown]
# ### 2. Create New Columns

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year.astype(int)
df['Month'] = df['Date'].dt.month.astype(int)
df['Day'] = df['Date'].dt.day.astype(int)
df.drop(columns=['Date'])
# Out:
#       AT  MinT  MaxT  PRE  AWS  MaxWD  MaxIWD  MaxWS  MaxIWS    RH   DT   CA  \
# 0   -4.3 -10.2   2.3  NaN  1.5      2       4    2.8     4.5  46.3  9.0  1.4
# 1   -1.3  -5.2   3.0  0.3  2.3     14      14    4.6     8.1  57.9  5.4  4.1
# 2   -1.9  -8.0   2.5  NaN  1.8     12      13    4.1     6.9  58.3  7.8  4.9
# 3   -2.5  -5.6   1.0  NaN  2.4     12      13    4.2     6.8  51.8  9.0  0.0
# 4   -2.8  -7.8   1.9  NaN  1.7      3       3    2.9     4.2  47.6  1.9  7.3
# ..   ...   ...   ...  ...  ...    ...     ...    ...     ...   ...  ...  ...
# 360 -2.6  -7.3   3.3  NaN  1.8     14      14    3.2     5.4  69.8  8.8  0.1
# 361 -3.3  -6.0   0.1  0.1  2.5     14      13    4.9     8.7  58.1  8.7  3.3
# 362 -2.9  -7.8   2.1  NaN  1.7     14      15    3.4     5.1  56.3  9.0  3.3
# 363 -1.8  -4.4   2.3  NaN  1.9     13      13    4.6     7.5  65.6  7.9  1.4
# 364 -1.2  -5.1   2.1  NaN  1.4     16       1    2.6     4.1  65.5  1.1  7.4
#
#      Result  Year  Month  Day
# 0    0.0125  2022      1    1
# 1    0.0164  2022      1    2
# 2    0.0086  2022      1    3
# 3    0.0170  2022      1    4
# 4    0.0062  2022      1    5
# ..      ...   ...    ...  ...
# 360  0.0066  2022     12   27
# 361  0.0180  2022     12   28
# 362  0.0127  2022     12   29
# 363  0.0150  2022     12   30
# 364  0.0074  2022     12   31
#
# [365 rows x 16 columns]

# %%
new_column_order = ['Year', 'Month', 'Day', 'AT', 'MinT', 'MaxT', 'PRE', 'AWS', 'MaxWD', 'MaxIWD', 'MaxWS', 'MaxIWS', 'RH', 'DT', 'CA', 'Result']
df = df.reindex(columns=new_column_order)

# %%
df
# Out:
#      Year  Month  Day   AT  MinT  MaxT  PRE  AWS  MaxWD  MaxIWD  MaxWS  \
# 0    2022      1    1 -4.3 -10.2   2.3  NaN  1.5      2       4    2.8
# 1    2022      1    2 -1.3  -5.2   3.0  0.3  2.3     14      14    4.6
# 2    2022      1    3 -1.9  -8.0   2.5  NaN  1.8     12      13    4.1
# 3    2022      1    4 -2.5  -5.6   1.0  NaN  2.4     12      13    4.2
# 4    2022      1    5 -2.8  -7.8   1.9  NaN  1.7      3       3    2.9
# ..    ...    ...  ...  ...   ...   ...  ...  ...    ...     ...    ...
# 360  2022     12   27 -2.6  -7.3   3.3  NaN  1.8     14      14    3.2
# 361  2022     12   28 -3.3  -6.0   0.1  0.1  2.5     14      13    4.9
# 362  2022     12   29 -2.9  -7.8   2.1  NaN  1.7     14      15    3.4
# 363  2022     12   30 -1.8  -4.4   2.3  NaN  1.9     13      13    4.6
# 364  2022     12   31 -1.2  -5.1   2.1  NaN  1.4     16       1    2.6
#
#      MaxIWS    RH   DT   CA  Result
# 0       4.5  46.3  9.0  1.4  0.0125
# 1       8.1  57.9  5.4  4.1  0.0164
# 2       6.9  58.3  7.8  4.9  0.0086
# 3       6.8  51.8  9.0  0.0  0.0170
# 4       4.2  47.6  1.9  7.3  0.0062
# ..      ...   ...  ...  ...     ...
# 360     5.4  69.8  8.8  0.1  0.0066
# 361     8.7  58.1  8.7  3.3  0.0180
# 362     5.1  56.3  9.0  3.3  0.0127
# 363     7.5  65.6  7.9  1.4  0.0150
# 364     4.1  65.5  1.1  7.4  0.0074
#
# [365 rows x 16 columns]

# %% [markdown]
# ## Heatmap

# %%
corr = df.corr()

sns.set_style('whitegrid')

sns.set_context('paper', font_scale=1.5)
plt.figure(figsize=(10, 8)) 
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Features Seletion

# %%
# Date New Columns
features = [
            'Year', 
            'Month',
            'Day',
            'AT', 
            'MinT', 
            'MaxT', 
            'PRE', 
            'AWS', 
            'MaxWD', 
            'MaxIWD', 
            'MaxWS',
            'MaxIWS', 
            'RH', 
            'DT', 
            'CA', 
           ]

# %% [markdown]
# ## Split train test

# %%
train, test = train_test_split(df, test_size=0.3, random_state=42)

# %%
display(train.head(), test.head())
# Out:
#      Year  Month  Day    AT  MinT  MaxT  PRE  AWS  MaxWD  MaxIWD  MaxWS  \
# 268  2022      9   26  20.0  14.8  25.4  NaN  1.7     12      12    3.5
# 231  2022      8   20  28.2  25.7  32.0  NaN  2.4     13      13    4.4
# 157  2022      6    7  20.6  15.1  25.1  NaN  2.7      3       4    5.2
# 19   2022      1   20  -5.0  -9.8   0.9  NaN  1.8     15      15    4.7
# 147  2022      5   28  22.3  15.0  29.3  NaN  2.8     11      10    6.8
#
#      MaxIWS    RH    DT   CA  Result
# 268     5.3  58.5   7.8  6.5  0.0278
# 231     8.1  80.0   9.6  4.8  0.0436
# 157    10.0  54.5   6.2  6.4  0.0324
# 19      7.0  63.5   9.1  0.0  0.0148
# 147    12.4  54.1  12.4  2.1  0.0527
#      Year  Month  Day    AT  MinT  MaxT    PRE  AWS  MaxWD  MaxIWD  MaxWS  \
# 193  2022      7   13  25.0  24.0  27.1  114.5  1.8      7       6    3.9
# 33   2022      2    3  -3.4  -6.9   0.4    NaN  2.4     13      13    4.6
# 15   2022      1   16  -2.0  -7.2   2.4    NaN  3.2     12      12    5.7
# 309  2022     11    6   9.6   3.7  16.4    NaN  1.8      9      14    3.3
# 57   2022      2   27   3.7  -1.6   9.1    NaN  2.8     12      10    7.4
#
#      MaxIWS    RH    DT    CA  Result
# 193     8.6  93.9   NaN  10.0  0.0190
# 33      8.2  52.4   9.7   1.5  0.0275
# 15      9.4  54.5   8.8   1.6  0.0200
# 309     5.5  60.5   9.6   2.6  0.0174
# 57     12.3  56.6  10.5   0.0  0.0320

# %%
target_variable = 'Result'

# %%
test_Result = test['Result']

# %%
test = test.drop(columns=[target_variable])

# %% [markdown]
# # Learning

# %%
X = train[features]
y = train[target_variable]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = CatBoostRegressor()

# %%
model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50)
# Out:
# Learning rate set to 0.038834
# 0:	learn: 0.0129480	test: 0.0114361	best: 0.0114361 (0)	total: 55.1ms	remaining: 55s
# 1:	learn: 0.0127321	test: 0.0112777	best: 0.0112777 (1)	total: 56ms	remaining: 28s
# 2:	learn: 0.0125378	test: 0.0111691	best: 0.0111691 (2)	total: 56.9ms	remaining: 18.9s
# 3:	learn: 0.0123593	test: 0.0110768	best: 0.0110768 (3)	total: 57.8ms	remaining: 14.4s
# 4:	learn: 0.0121238	test: 0.0109442	best: 0.0109442 (4)	total: 58.6ms	remaining: 11.7s
# 5:	learn: 0.0119314	test: 0.0108111	best: 0.0108111 (5)	total: 59.4ms	remaining: 9.84s
# 6:	learn: 0.0117609	test: 0.0107062	best: 0.0107062 (6)	total: 60.2ms	remaining: 8.54s
# 7:	learn: 0.0115822	test: 0.0105702	best: 0.0105702 (7)	total: 61ms	remaining: 7.57s
# 90:	learn: 0.0054367	test: 0.0078478	best: 0.0078478 (90)	total: 133ms	remaining: 1.33s
# 91:	learn: 0.0054155	test: 0.0078400	best: 0.0078400 (91)	total: 134ms	remaining: 1.32s
# 92:	learn: 0.0053800	test: 0.0078286	best: 0.0078286 (92)	total: 135ms	remaining: 1.32s
# 93:	learn: 0.0053533	test: 0.0078245	best: 0.0078245 (93)	total: 136ms	remaining: 1.31s
# 94:	learn: 0.0053349	test: 0.0078238	best: 0.0078238 (94)	total: 137ms	remaining: 1.3s
# 95:	learn: 0.0053152	test: 0.0078262	best: 0.0078238 (94)	total: 137ms	remaining: 1.29s
# 96:	learn: 0.0052922	test: 0.0078276	best: 0.0078238 (94)	total: 138ms	remaining: 1.29s
# 97:	learn: 0.0052622	test: 0.0078233	best: 0.0078233 (97)	total: 139ms	remaining: 1.28s
# 98:	learn: 0.0052337	test: 0.0078244	best: 0.0078233 (97)	total: 140ms	remaining: 1.27s
# 99:	learn: 0.0052116	test: 0.0078150	best: 0.0078150 (99)	total: 141ms	remaining: 1.27s
# 100:	learn: 0.0051923	test: 0.0078167	best: 0.0078150 (99)	total: 142ms	remaining: 1.26s
# 101:	learn: 0.0051672	test: 0.0078182	best: 0.0078150 (99)	total: 142ms	remaining: 1.25s
# 102:	learn: 0.0051413	test: 0.0078201	best: 0.0078150 (99)	total: 143ms	remaining: 1.25s
# 103:	learn: 0.0051074	test: 0.0078116	best: 0.0078116 (103)	total: 144ms	remaining: 1.24s
# 104:	learn: 0.0050870	test: 0.0078069	best: 0.0078069 (104)	total: 145ms	remaining: 1.23s
# 105:	learn: 0.0050630	test: 0.0077970	best: 0.0077970 (105)	total: 146ms	remaining: 1.23s
# 106:	learn: 0.0050354	test: 0.0078051	best: 0.0077970 (105)	total: 146ms	remaining: 1.22s
# 107:	learn: 0.0050206	test: 0.0078050	best: 0.0077970 (105)	total: 147ms	remaining: 1.22s
# 108:	learn: 0.0049914	test: 0.0078027	best: 0.0077970 (105)	total: 148ms	remaining: 1.21s
# 109:	learn: 0.0049736	test: 0.0077999	best: 0.0077970 (105)	total: 149ms	remaining: 1.2s
# 110:	learn: 0.0049432	test: 0.0077996	best: 0.0077970 (105)	total: 150ms	remaining: 1.2s
# 111:	learn: 0.0049149	test: 0.0077988	best: 0.0077970 (105)	total: 150ms	remaining: 1.19s
# 112:	learn: 0.0048874	test: 0.0077979	best: 0.0077970 (105)	total: 151ms	remaining: 1.19s
# 113:	learn: 0.0048545	test: 0.0077898	best: 0.0077898 (113)	total: 152ms	remaining: 1.18s
# 114:	learn: 0.0048227	test: 0.0077825	best: 0.0077825 (114)	total: 153ms	remaining: 1.18s
# 115:	learn: 0.0048010	test: 0.0077830	best: 0.0077825 (114)	total: 154ms	remaining: 1.17s
# 116:	learn: 0.0047871	test: 0.0077740	best: 0.0077740 (116)	total: 155ms	remaining: 1.17s
# 117:	learn: 0.0047548	test: 0.0077692	best: 0.0077692 (117)	total: 155ms	remaining: 1.16s
# 118:	learn: 0.0047286	test: 0.0077689	best: 0.0077689 (118)	total: 156ms	remaining: 1.16s
# 119:	learn: 0.0046988	test: 0.0077698	best: 0.0077689 (118)	total: 157ms	remaining: 1.15s
# 120:	learn: 0.0046757	test: 0.0077812	best: 0.0077689 (118)	total: 158ms	remaining: 1.15s
# 121:	learn: 0.0046522	test: 0.0077778	best: 0.0077689 (118)	total: 159ms	remaining: 1.14s
# 122:	learn: 0.0046360	test: 0.0077829	best: 0.0077689 (118)	total: 160ms	remaining: 1.14s
# 123:	learn: 0.0046140	test: 0.0077847	best: 0.0077689 (118)	total: 161ms	remaining: 1.13s
# 124:	learn: 0.0045826	test: 0.0077856	best: 0.0077689 (118)	total: 161ms	remaining: 1.13s
# 125:	learn: 0.0045530	test: 0.0077818	best: 0.0077689 (118)	total: 162ms	remaining: 1.12s
# 126:	learn: 0.0045293	test: 0.0077805	best: 0.0077689 (118)	total: 163ms	remaining: 1.12s
# 127:	learn: 0.0045016	test: 0.0077692	best: 0.0077689 (118)	total: 164ms	remaining: 1.12s
# 128:	learn: 0.0044853	test: 0.0077724	best: 0.0077689 (118)	total: 165ms	remaining: 1.11s
# 129:	learn: 0.0044602	test: 0.0077779	best: 0.0077689 (118)	total: 166ms	remaining: 1.11s
# 130:	learn: 0.0044398	test: 0.0077731	best: 0.0077689 (118)	total: 166ms	remaining: 1.1s
# 131:	learn: 0.0044199	test: 0.0077755	best: 0.0077689 (118)	total: 167ms	remaining: 1.1s
# 132:	learn: 0.0043951	test: 0.0077700	best: 0.0077689 (118)	total: 168ms	remaining: 1.09s
# 133:	learn: 0.0043724	test: 0.0077670	best: 0.0077670 (133)	total: 169ms	remaining: 1.09s
# 134:	learn: 0.0043445	test: 0.0077694	best: 0.0077670 (133)	total: 170ms	remaining: 1.09s
# 135:	learn: 0.0043256	test: 0.0077755	best: 0.0077670 (133)	total: 171ms	remaining: 1.08s
# 136:	learn: 0.0043039	test: 0.0077785	best: 0.0077670 (133)	total: 171ms	remaining: 1.08s
# 137:	learn: 0.0042821	test: 0.0077817	best: 0.0077670 (133)	total: 174ms	remaining: 1.08s
# 138:	learn: 0.0042619	test: 0.0077888	best: 0.0077670 (133)	total: 175ms	remaining: 1.08s
# 139:	learn: 0.0042335	test: 0.0077866	best: 0.0077670 (133)	total: 176ms	remaining: 1.08s
# 140:	learn: 0.0042234	test: 0.0078035	best: 0.0077670 (133)	total: 177ms	remaining: 1.08s
# 141:	learn: 0.0041940	test: 0.0078009	best: 0.0077670 (133)	total: 178ms	remaining: 1.07s
# 142:	learn: 0.0041732	test: 0.0077996	best: 0.0077670 (133)	total: 178ms	remaining: 1.07s
# 143:	learn: 0.0041647	test: 0.0077944	best: 0.0077670 (133)	total: 179ms	remaining: 1.06s
# 144:	learn: 0.0041489	test: 0.0077902	best: 0.0077670 (133)	total: 180ms	remaining: 1.06s
# 145:	learn: 0.0041152	test: 0.0077843	best: 0.0077670 (133)	total: 181ms	remaining: 1.06s
# 146:	learn: 0.0041016	test: 0.0077894	best: 0.0077670 (133)	total: 182ms	remaining: 1.05s
# 147:	learn: 0.0040860	test: 0.0077864	best: 0.0077670 (133)	total: 182ms	remaining: 1.05s
# 148:	learn: 0.0040568	test: 0.0077878	best: 0.0077670 (133)	total: 183ms	remaining: 1.04s
# 149:	learn: 0.0040387	test: 0.0077828	best: 0.0077670 (133)	total: 184ms	remaining: 1.04s
# 150:	learn: 0.0040297	test: 0.0077815	best: 0.0077670 (133)	total: 185ms	remaining: 1.04s
# 151:	learn: 0.0040091	test: 0.0077782	best: 0.0077670 (133)	total: 186ms	remaining: 1.03s
# 152:	learn: 0.0039904	test: 0.0077859	best: 0.0077670 (133)	total: 186ms	remaining: 1.03s
# 153:	learn: 0.0039789	test: 0.0077901	best: 0.0077670 (133)	total: 187ms	remaining: 1.03s
# 154:	learn: 0.0039576	test: 0.0077890	best: 0.0077670 (133)	total: 188ms	remaining: 1.02s
# 155:	learn: 0.0039358	test: 0.0077973	best: 0.0077670 (133)	total: 189ms	remaining: 1.02s
# 156:	learn: 0.0039177	test: 0.0078045	best: 0.0077670 (133)	total: 190ms	remaining: 1.02s
# 157:	learn: 0.0038998	test: 0.0078163	best: 0.0077670 (133)	total: 191ms	remaining: 1.01s
# 158:	learn: 0.0038786	test: 0.0078239	best: 0.0077670 (133)	total: 191ms	remaining: 1.01s
# 159:	learn: 0.0038594	test: 0.0078185	best: 0.0077670 (133)	total: 192ms	remaining: 1.01s
# 160:	learn: 0.0038473	test: 0.0078161	best: 0.0077670 (133)	total: 193ms	remaining: 1s
# 161:	learn: 0.0038277	test: 0.0078186	best: 0.0077670 (133)	total: 194ms	remaining: 1s
# 162:	learn: 0.0038113	test: 0.0078220	best: 0.0077670 (133)	total: 195ms	remaining: 1s
# 163:	learn: 0.0037949	test: 0.0078244	best: 0.0077670 (133)	total: 196ms	remaining: 998ms
# 164:	learn: 0.0037875	test: 0.0078240	best: 0.0077670 (133)	total: 197ms	remaining: 995ms
# 165:	learn: 0.0037739	test: 0.0078239	best: 0.0077670 (133)	total: 197ms	remaining: 992ms
# 166:	learn: 0.0037561	test: 0.0078263	best: 0.0077670 (133)	total: 198ms	remaining: 989ms
# 167:	learn: 0.0037318	test: 0.0078180	best: 0.0077670 (133)	total: 199ms	remaining: 985ms
# 168:	learn: 0.0037155	test: 0.0078206	best: 0.0077670 (133)	total: 200ms	remaining: 982ms
# 169:	learn: 0.0037019	test: 0.0078181	best: 0.0077670 (133)	total: 201ms	remaining: 979ms
# 170:	learn: 0.0036917	test: 0.0078147	best: 0.0077670 (133)	total: 202ms	remaining: 977ms
# 171:	learn: 0.0036769	test: 0.0078220	best: 0.0077670 (133)	total: 202ms	remaining: 974ms
# 172:	learn: 0.0036665	test: 0.0078238	best: 0.0077670 (133)	total: 203ms	remaining: 971ms
# 173:	learn: 0.0036477	test: 0.0078292	best: 0.0077670 (133)	total: 204ms	remaining: 968ms
# 174:	learn: 0.0036433	test: 0.0078334	best: 0.0077670 (133)	total: 205ms	remaining: 965ms
# 175:	learn: 0.0036308	test: 0.0078393	best: 0.0077670 (133)	total: 205ms	remaining: 962ms
# 176:	learn: 0.0036109	test: 0.0078462	best: 0.0077670 (133)	total: 206ms	remaining: 960ms
# 177:	learn: 0.0035986	test: 0.0078500	best: 0.0077670 (133)	total: 207ms	remaining: 957ms
# 178:	learn: 0.0035832	test: 0.0078562	best: 0.0077670 (133)	total: 208ms	remaining: 954ms
# 179:	learn: 0.0035681	test: 0.0078550	best: 0.0077670 (133)	total: 209ms	remaining: 951ms
# 180:	learn: 0.0035523	test: 0.0078537	best: 0.0077670 (133)	total: 209ms	remaining: 948ms
# 181:	learn: 0.0035351	test: 0.0078609	best: 0.0077670 (133)	total: 210ms	remaining: 945ms
# 182:	learn: 0.0035292	test: 0.0078663	best: 0.0077670 (133)	total: 211ms	remaining: 942ms
# 183:	learn: 0.0035169	test: 0.0078753	best: 0.0077670 (133)	total: 212ms	remaining: 940ms
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.007767042945
# bestIteration = 133
#
# Shrink model to first 134 iterations.

# %% [markdown]
# # Predict

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.03206142, 0.03529124, 0.01531653, 0.02846715, 0.03130307,
#        0.02015983, 0.03816282, 0.01635344, 0.04327849, 0.02284551,
#        0.02536732, 0.03439785, 0.03125933, 0.0218415 , 0.01613135,
#        0.03076167, 0.01780087, 0.04156323, 0.03633468, 0.01315163,
#        0.03624897, 0.04208109, 0.02569486, 0.02440682, 0.04118321,
#        0.04826261, 0.02944164, 0.0297282 , 0.02254638, 0.02760653,
#        0.02973604, 0.02202656, 0.01921097, 0.02471588, 0.03742734,
#        0.02544889, 0.04008525, 0.04591076, 0.02147695, 0.03207546,
#        0.02936413, 0.02589334, 0.01473947, 0.01386127, 0.02064681,
#        0.01887671, 0.02466436, 0.02991393, 0.02852125, 0.02841324,
#        0.01915935, 0.0305696 , 0.04397212, 0.02136372, 0.01241878,
#        0.02578113, 0.04368898, 0.04252567, 0.04496993, 0.02397416,
#        0.02211223, 0.01358614, 0.01321319, 0.03021738, 0.03354271,
#        0.02931836, 0.03917296, 0.02636562, 0.04004475, 0.03319705,
#        0.02380871, 0.04456043, 0.01830501, 0.02828506, 0.03211393,
#        0.02903829, 0.02939464])

# %% [markdown]
# # Model Evaluation Metrics

# %% [markdown]
# ### MSE

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 5.526886350193444e-05

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# #### 1. Catboost importance

# %%
importances = model.get_feature_importance()
for feature, importance in zip(features, importances):
    print(f"{feature}: {importance}")
# Out:
# Year: 0.0
# Month: 17.567516106016665
# Day: 3.1345231108946603
# AT: 10.819194614228145
# MinT: 8.198516086671352
# MaxT: 16.656777321059778
# PRE: 4.049536481435748
# AWS: 6.395492451725643
# MaxWD: 4.722325152193874
# MaxIWD: 2.187345584509834
# MaxWS: 5.45921766299713
# MaxIWS: 6.120680742966833
# RH: 4.54732329400635
# DT: 7.043414665646233
# CA: 3.098136725647753

# %% [markdown]
# #### 2. MI Score

# %%
X_mi = train[features]

X_mi.fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_33/2948845674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mi.fillna(0, inplace=True)

# %%
y_mi = train[target_variable]
mi_scores = mutual_info_regression(X_mi, y_mi)
mi_scores = pd.Series(mi_scores, name='MI Scores', index=X_mi.columns)
mi_scores = mi_scores.sort_values(ascending=False)
print(mi_scores)
# Out:
# Month     0.484172
# AT        0.282649
# MaxT      0.231651
# MinT      0.179376
# DT        0.080127
# AWS       0.079964
# PRE       0.056284
# MaxWD     0.054235
# MaxWS     0.035787
# Year      0.030598
# MaxIWD    0.014365
# Day       0.000000
# MaxIWS    0.000000
# RH        0.000000
# CA        0.000000
# Name: MI Scores, dtype: float64

# %% [markdown]
# #### 3. RF

# %%
X_rf = train[features]

y_rf = train[target_variable]
X_rf.fillna(0, inplace=True)
rf = RandomForestRegressor(random_state=42)
rf.fit(X_rf, y_rf)

importances = pd.DataFrame({'Feature':X_rf.columns, 'Importance':rf.feature_importances_})
importances = importances.sort_values('Importance', ascending=False)

importances
# Out:
# /tmp/ipykernel_33/2929343439.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_rf.fillna(0, inplace=True)
#    Feature  Importance
# 3       AT    0.189687
# 1    Month    0.178442
# 5     MaxT    0.155828
# 4     MinT    0.071017
# 13      DT    0.070885
# 7      AWS    0.068548
# 12      RH    0.061852
# 2      Day    0.043616
# 11  MaxIWS    0.038943
# 14      CA    0.035442
# 10   MaxWS    0.034188
# 8    MaxWD    0.025527
# 9   MaxIWD    0.017572
# 6      PRE    0.008453
# 0     Year    0.000000

# %% [markdown]
# # Contrast

# %%
results = model.predict(test)

# %%
df_result1 = pd.DataFrame(test_Result)
df_result2 = pd.DataFrame(results)

# %%
matches = (np.array(df_result1['Result']) == np.array(df_result2[0])).sum()
accuracy = matches / len(df_result1)

print(accuracy)
# Out:
# 0.0

# %%
diff = np.abs(np.array(df_result1['Result']) - np.array(df_result2[0]))
mean_absolute_difference = np.mean(diff)

print(mean_absolute_difference)
# Out:
# 0.005961741218268345

# %% [markdown]
# # Optuna

# %%
def objective_catboost(trial):
    params = {
    'iterations': trial.suggest_int('iterations', 500, 3000),
    'learning_rate': trial.suggest_loguniform('learning_rate', 0.0001, 0.5),
    'depth': trial.suggest_int('depth', 4, 16),
    'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-6, 10),
    'random_strength': trial.suggest_loguniform('random_strength', 1e-6, 100),
    'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.01, 10),
    'od_type': 'Iter',
    'od_wait': 50,
    'eval_metric': 'RMSE',
    'loss_function': 'RMSE',
    'verbose': False,
    'random_state': 42,
    'rsm': trial.suggest_uniform('rsm', 0.5, 1.0)
    }
    model = CatBoostRegressor(**params)
    model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50)

    y_pred = model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

study_catboost = optuna.create_study(direction='minimize')
study_catboost.optimize(objective_catboost, n_trials=30)

print("CatBoost - Best trial:")
print(study_catboost.best_trial.params)
print("CatBoost - Best MSE:")
print(study_catboost.best_value)
# Out:
# [I 2023-06-29 12:51:00,142] A new study created in memory with name: no-name-b52bd2a2-8fed-49ee-a886-d5c3ac90fdc7
# /tmp/ipykernel_33/3923948306.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.0001, 0.5),
# /tmp/ipykernel_33/3923948306.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-6, 10),
# /tmp/ipykernel_33/3923948306.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 1e-6, 100),
# /tmp/ipykernel_33/3923948306.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.01, 10),
# /tmp/ipykernel_33/3923948306.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'rsm': trial.suggest_uniform('rsm', 0.5, 1.0)
# [W 2023-06-29 12:51:35,057] Trial 0 failed with parameters: {'iterations': 530, 'learning_rate': 0.28575233925265453, 'depth': 14, 'l2_leaf_reg': 8.836125927690796, 'random_strength': 0.3085871058131987, 'bagging_temperature': 0.013694027730313382, 'rsm': 0.7071324863546244} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_33/3923948306.py", line 18, in objective_catboost
#     model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50)
#   File "/opt/conda/lib/python3.10/site-packages/catboost/core.py", line 5734, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#   File "/opt/conda/lib/python3.10/site-packages/catboost/core.py", line 2357, in _fit
#     self._train(
#   File "/opt/conda/lib/python3.10/site-packages/catboost/core.py", line 1761, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4624, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4673, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-06-29 12:51:35,061] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 24
#      21     return mean_squared_error(y_test, y_pred)
#      23 study_catboost = optuna.create_study(direction='minimize')
# ---> 24 study_catboost.optimize(objective_catboost, n_trials=30)
#      26 print("CatBoost - Best trial:")
#      27 print(study_catboost.best_trial.params)
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/study.py:443, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     339 def optimize(
#     340     self,
#     341     func: ObjectiveFuncType,
#    (...)
#     348     show_progress_bar: bool = False,
#     349 ) -> None:
#     350     """Optimize an objective function.
#     351
#     352     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     440             If nested invocation of this method occurs.
#     441     """
# --> 443     _optimize(
#     444         study=self,
#     445         func=func,
#     446         n_trials=n_trials,
#     447         timeout=timeout,
#     448         n_jobs=n_jobs,
#     449         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     450         callbacks=callbacks,
#     451         gc_after_trial=gc_after_trial,
#     452         show_progress_bar=show_progress_bar,
#     453     )
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[50], line 18, in objective_catboost(trial)
#       2 params = {
#       3 'iterations': trial.suggest_int('iterations', 500, 3000),
#       4 'learning_rate': trial.suggest_loguniform('learning_rate', 0.0001, 0.5),
#    (...)
#      15 'rsm': trial.suggest_uniform('rsm', 0.5, 1.0)
#      16 }
#      17 model = CatBoostRegressor(**params)
# ---> 18 model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50)
#      20 y_pred = model.predict(X_test)
#      21 return mean_squared_error(y_test, y_pred)
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:5734, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5731 if 'loss_function' in params:
#    5732     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5734 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5735                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5736                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5737                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:2357, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2353 allow_clear_pool = train_params["allow_clear_pool"]
#    2355 with log_fixup(log_cout, log_cerr), \
#    2356     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2357     self._train(
#    2358         train_pool,
#    2359         train_params["eval_sets"],
#    2360         params,
#    2361         allow_clear_pool,
#    2362         train_params["init_model"]
#    2363     )
#    2365 # Have property feature_importance possibly set
#    2366 loss = self._object._get_loss_function_name()
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:1761, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1760 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1761     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1762     self._set_trained_model_attributes()
#
# File _catboost.pyx:4624, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4673, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
best_iterations = study_catboost.best_trial.params['iterations']
best_learning_rate = study_catboost.best_trial.params['learning_rate']
best_depth = study_catboost.best_trial.params['depth']
best_l2_leaf_reg = study_catboost.best_trial.params['l2_leaf_reg']
best_random_strength = study_catboost.best_trial.params['random_strength']
best_bagging_temperature = study_catboost.best_trial.params['bagging_temperature']
best_rsm = study_catboost.best_trial.params['rsm']

catboost = CatBoostRegressor(iterations=best_iterations,
                             learning_rate=best_learning_rate,
                             depth=best_depth, 
                             l2_leaf_reg=best_l2_leaf_reg,
                             random_strength=best_random_strength,
                             bagging_temperature=best_bagging_temperature,
                             rsm = best_rsm)

catboost.fit(X_train, y_train)

y_pred_catboost = catboost.predict(X_test)
mse_catboost = mean_squared_error(y_test, y_pred_catboost)
print("CatBoost - Test MSE:", mse_catboost)
